# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

# %%
x = torch.load('Training_Checkpoints//loss')
x[::100][['validation_loss','training_loss']].rolling(1).mean().plot(grid=True)
x[::100][['validation_accuracy','training_accuracy']].rolling(1).mean()[:].plot(grid=True)
# Out:
# <AxesSubplot:>
